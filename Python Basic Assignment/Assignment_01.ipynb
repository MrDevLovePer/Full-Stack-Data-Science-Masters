# %% [markdown]
# # Assignment-1

# %% [markdown]
# #### 1) In the below elements which of them are values or an expression? eg:- values can be or string and expressions will be mathematical operators. *, 'hello', -87.8, -, /, +
# ----------------------------------------------------------------------
#
# <table>
#    <tr>
#        <th><b>Values</b></th>
#        <th><b>Expressions</b></th>
#   </tr>
#   <tr>
#     <td>'hello'</td>
#     <td>* </td>
#   </tr>
#   <tr>
#     <td>-87.8</td>
#     <td> - </td>
#   </tr>
#   <tr>
#     <td> 6 </td>
#     <td> / </td>
#   </tr>
# </table>
#
#
#
#
# #### 2) What is the difference between string and variable?
# -----------------------------------------------------------------
#
# A string is a sequence of one or more characters (letters, numbers, symbols) that can be either a constant or a variable. Made up of Unicode, strings are immutable sequences, meaning they are unchanging.
#
# String might be a variable with some specific conditions, variable should not be separated by the spaces, must start with alphabet, and may start with underscore in some specific cases. Moreover varibale is used to asign a value.
#
# The major visual difference is string is represented by quotes(single/double/triple). The variable is set without quotes with specific conditions as mentioned above.
#
#
#
#
#
# #### 3) Describe three different data types.
# -----------------------------------------------------------------
#
# str: str is a string data type in python, which is immutabe and iterable. In one sentence, string is a sequence of characters.
# ex: 'sudh', 'ineuron', 'cyberdev', 'f_s_d_s',etc
#
# int: int is a integer datatype where it stores integer values, ex: 1, 44, 33, -45, etc
#
# Float: float can store only floating values such as 233.33, 22.2, etc.
#
#
#
#
#
# #### 4) What is an expression made up of? What do all expressions do?
# ---------------------------------------------------------------------
#
# Expression is made up of values, containers, and mathematical operators (operands) e.g
# a = 2 + 3 and expressions are used to evaluate the values or represent the result on the screen.
#
#
#
#
# #### 5) This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# -----------------------------------------------------------------
#
# Expression is made up of values, containers, and mathematical operators, and the statement is just like a command that a python interpreter executes.
#
#
#
#
# #### 6) After running the following code, what does the variable bacon contain?
#     bacon = 22
#     bacon + 1
# -----------------------------------------------------------------
# However bacon+1 gives 23. But,
# The variable bacon still contain the value as 22. Since, it was not assigned.
#
#
#
#
#
# #### 7) What should the values of the following two terms be?
#     'spam' + 'spamspam'
#     'spam' * 3
# -----------------------------------------------------------------
#
# spamspamspam
# spamspamspam
#
#
# #### 8) Why is eggs a valid variable name while 100 is invalid?
# -----------------------------------------------------------------
#
# variables should never start with a numeric or integer. It always starts with an alphabet or underscore in some specific cases.
#
# #### 9) What three functions can be used to get the integer, floating-point number, or string version of a value?
# -----------------------------------------------------------------
#
# int()
# float()
# str()
#
# #### 10) Why does this expression cause an error? How can you fix it?
#
#     'I have eaten' + 99 + 'burritos'
# -----------------------------------------------------------------
# TypeError: can only concatenate str (not "int") to str
#
# Python is a dynamically typed language. string and numeric/integer datatype  cannot be concatinated here.
# Solution is, convert that integer to string by typecasting.
#
#     'I have eaten' + str(99) + 'burritos'
